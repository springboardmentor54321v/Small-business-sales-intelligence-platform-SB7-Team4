# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import sys
import os

sys.path.append(os.path.abspath(".."))

from stub_service.feature_engineering import create_features

# %%
df=pd.read_csv("../data/dataset.csv")

# %%
df=create_features(df)
# Out:
# c:\Users\Rakshitha\OneDrive\Desktop\infosys internship\Small-business-sales-intelligence-platform-SB7-Team4\AIML\feature_engineering.py:6: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
def season(month):
    if month in [12,1,2]:
        return "Winter"
    elif month in [3,4,5]:
        return "Summer"
    elif month in [6,7,8]:
        return "Monsoon"
    else:
        return "Autumn"

df["season"] = df["month"].apply(season)

# %%
daily_sales = df.groupby("Order Date")["Total amount"].sum().reset_index()

# %%
weekly_sales = df.groupby(["year","weekofyear"])["Total amount"].sum().reset_index()

# %%
df.to_csv("cleaned_dataset.csv", index=False)

daily_sales.to_csv("daily_sales.csv", index=False)

weekly_sales.to_csv("weekly_sales.csv", index=False)
